# %% [markdown]
# # AECTech2025 Hackathon - SIMON

# %%
from pathlib import Path
import numpy as np
import json

# %%
DATA_DIR = Path("/Users/vincentmai/Projects/AECTech_2025/11_15_2025/keyframes")
CAMERA_DIR = Path(DATA_DIR / "corrected_cameras")

# %% [markdown]
# ## Utility Functions

# %%
def parse_camera_matrix(camera_data):
    # for k, v in camera_data.items(): print(f"{k}: {v}")
    orientation = np.zeros(3)
    for j in range(3):
        axis_component = np.array([camera_data[f"t_{i}{j}"] for i in range(3)])
        orientation += axis_component
    pos = np.array([camera_data[f"t_{k}3"] for k in range(3)])
    return pos, orientation

# %%
for file_path in CAMERA_DIR.rglob("*.json"):
    with open(file_path, 'r') as f:
        print(file_path)
        data = json.load(f)
        pos, orientation = parse_camera_matrix(data)
        print(orientation, pos)
        break
# Out:
# /Users/vincentmai/Projects/AECTech_2025/11_15_2025/keyframes/corrected_cameras/435536954932.json
# [-0.9483456  -1.01197144  1.03757143] [4.56046915 0.47626263 0.4776316 ]
